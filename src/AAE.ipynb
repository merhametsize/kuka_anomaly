# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn
import tensorflow as tf
import keras

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras import Model, layers
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-07-02 17:10:16.226387: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # Global settings

# %%
mode = 'pca' # 'mean' averages the 86 components, '86' keeps them, 'pca' reduces them to pca_dim
model = 'conv' # 'conv' | 'lstm'

sequence_length = 20
epochs = 10
pca_dim = 20

# %% [markdown]
# # Data loading

# %%
data_normal = np.load('KukaNormal.npy')
data_slow = np.load('KukaSlow.npy')[:, 0:-1]       #Discards the label column
dimensions = np.load('KukaColumnNames.npy')[0:-1]  #Discards the label
data = np.concatenate((data_normal, data_slow))

target_normal = np.zeros(data_normal.shape[0])
target_slow = np.ones(data_slow.shape[0])
target = np.concatenate((target_normal, target_slow))

df_normal = pd.DataFrame(data_normal, columns=dimensions)
df_slow = pd.DataFrame(data_slow, columns=dimensions)
df_normal.tail()
# Out:
#         action  machine_nameKuka Robot_apparent_power  \
# 233787     0.0                             160.462463
# 233788     0.0                             160.462463
# 233789     0.0                             160.462463
# 233790     0.0                             160.462463
# 233791     0.0                             160.462463
#
#         machine_nameKuka Robot_current  machine_nameKuka Robot_frequency  \
# 233787                        0.993556                              50.0
# 233788                        0.993556                              50.0
# 233789                        0.993556                              50.0
# 233790                        0.993556                              50.0
# 233791                        0.993556                              50.0
#
#         machine_nameKuka Robot_phase_angle  machine_nameKuka Robot_power  \
# 233787                          321.580872                    125.725021
# 233788                          321.580872                    125.725021
# 233789                          321.580872                    125.725021
# 233790                          321.580872                    125.725021
# 233791                          321.580872                    125.725021
#
#         machine_nameKuka Robot_power_factor  \
# 233787                             0.783517
# 233788                             0.783517
# 233789                             0.783517
# 233790                             0.783517
# 233791                             0.783517
#
#         machine_nameKuka Robot_reactive_power  machine_nameKuka Robot_voltage  \
# 233787                             -99.697563                       231.03653
# 233788                             -99.697563                       231.03653
# 233789                             -99.697563                       231.03653
# 233790                             -99.697563                       231.03653
# 233791                             -99.697563                       231.03653
#
#         sensor_id1_AccX  ...  sensor_id7_AccY  sensor_id7_AccZ  \
# 233787        -0.754395  ...        -0.002441         1.000488
# 233788        -0.750977  ...        -0.002930         1.000977
# 233789        -0.754395  ...        -0.003418         0.999512
# 233790        -0.762695  ...        -0.004883         1.000000
# 233791        -0.747559  ...        -0.003906         1.002441
#
#         sensor_id7_GyroX  sensor_id7_GyroY  sensor_id7_GyroZ  sensor_id7_q1  \
# 233787          0.000000          0.000000               0.0      -0.172724
# 233788          0.000000          0.000000               0.0      -0.172724
# 233789          0.000000          0.000000               0.0      -0.172724
# 233790          0.000000          0.061035               0.0      -0.172932
# 233791         -0.061035          0.000000               0.0      -0.172956
#
#         sensor_id7_q2  sensor_id7_q3  sensor_id7_q4  sensor_id7_temp
# 233787      -0.048044       0.251768       0.951037           180.24
# 233788      -0.048044       0.251768       0.951037           180.24
# 233789      -0.048044       0.251768       0.951037           180.24
# 233790      -0.048179       0.251648       0.951024           180.24
# 233791      -0.048274       0.251584       0.951032           180.24
#
# [5 rows x 86 columns]

# %% [markdown]
# # Plots

# %%
rows, columns = 5, 2
samples = 300

fig, ax = plt.subplots(rows, columns, figsize=(15, 5))
for r in range(rows):
    for c in range(columns):
        sensor = np.random.randint(len(dimensions))
        ax[r][c].plot(data_normal[0:samples, sensor], label=dimensions[sensor])
        ax[r][c].legend()

# %% [markdown]
# #Preprocessing

# %%
if mode == 'mean':
    data_normal = np.mean(data_normal, axis=1)
    data_slow = np.mean(data_slow, axis=1)

# %%
df_normal = pd.DataFrame(data_normal)
df_normal.tail()
# Out:
#          0           1         2     3           4           5         6   \
# 233787  0.0  160.462463  0.993556  50.0  321.580872  125.725021  0.783517
# 233788  0.0  160.462463  0.993556  50.0  321.580872  125.725021  0.783517
# 233789  0.0  160.462463  0.993556  50.0  321.580872  125.725021  0.783517
# 233790  0.0  160.462463  0.993556  50.0  321.580872  125.725021  0.783517
# 233791  0.0  160.462463  0.993556  50.0  321.580872  125.725021  0.783517
#
#                7          8         9   ...        76        77        78  \
# 233787 -99.697563  231.03653 -0.754395  ... -0.002441  1.000488  0.000000
# 233788 -99.697563  231.03653 -0.750977  ... -0.002930  1.000977  0.000000
# 233789 -99.697563  231.03653 -0.754395  ... -0.003418  0.999512  0.000000
# 233790 -99.697563  231.03653 -0.762695  ... -0.004883  1.000000  0.000000
# 233791 -99.697563  231.03653 -0.747559  ... -0.003906  1.002441 -0.061035
#
#               79   80        81        82        83        84      85
# 233787  0.000000  0.0 -0.172724 -0.048044  0.251768  0.951037  180.24
# 233788  0.000000  0.0 -0.172724 -0.048044  0.251768  0.951037  180.24
# 233789  0.000000  0.0 -0.172724 -0.048044  0.251768  0.951037  180.24
# 233790  0.061035  0.0 -0.172932 -0.048179  0.251648  0.951024  180.24
# 233791  0.000000  0.0 -0.172956 -0.048274  0.251584  0.951032  180.24
#
# [5 rows x 86 columns]

# %%
if mode == 'mean':
    data_normal = data_normal.reshape(-1, 1) # (N,) ---> (N, 1)
    data_slow = data_slow.reshape(-1, 1)

ss = MinMaxScaler().fit(data_normal)
data_normal = ss.transform(data_normal)
data_slow = ss.transform(data_slow)

# %%
if mode == 'pca':
    pca = PCA(n_components=pca_dim)
    pca.fit(data_normal)
    data_normal = pca.transform(data_normal)
    data_slow = pca.transform(data_slow)

# %%
if mode == 'mean':
    n_points = 1000
    dimension = 11

    fig, ax = plt.subplots(1, 1, figsize=(17, 5))
    if mode == 'mean':
        ax.plot(data_normal[0:n_points], color='green', label='Normal signal');
        ax.plot(data_slow[0:n_points], color='red', label='Anomalous signal');
    else:
        ax.plot(data_normal[0:n_points, dimension], color='green', label='Normal signal');
        ax.plot(data_slow[0:n_points, dimension], color='red', label='Anomalous signal');
    ax.legend();

# %% [markdown]
# # Data windowing
#
# The shape of the dataset passes from (N, 1) to (N, s, 1), where s is the sequence length.

# %%
data_normal = np.array([data_normal[i:i+sequence_length,:] for i in range(0, len(data_normal)-sequence_length)])
data_slow = np.array([data_slow[i:i+sequence_length,:] for i in range(0, len(data_slow)-sequence_length)])
print(data_normal.shape)
print(data_slow.shape)
# Out:
# (233772, 20, 20)
# (41518, 20, 20)

# %% [markdown]
# ### Sequence display
# Only considering sensor 10

# %%
if mode == 'mean':
    fig, ax = plt.subplots(2, 2, figsize=(15, 5))
    ax[0][0].plot(data_normal[np.random.randint(len(data_normal))].squeeze(), label='Normal signal', color='green')
    ax[0][1].plot(data_normal[np.random.randint(len(data_normal))].squeeze(), label='Normal signal', color='green')
    ax[1][0].plot(data_slow[np.random.randint(len(data_slow))].squeeze(), label='Anomalous signal', color='red')
    ax[1][1].plot(data_slow[np.random.randint(len(data_slow))].squeeze(), label='Anomalous signal', color='red')
elif (mode == '86' or mode == 'pca'):
    fig, ax = plt.subplots(2, 2, figsize=(15, 5))
    ax[0][0].plot(data_normal[np.random.randint(len(data_normal)), :, 10], label='Normal signal', color='green')
    ax[0][1].plot(data_normal[np.random.randint(len(data_normal)), :, 10], label='Normal signal', color='green')
    ax[1][0].plot(data_slow[np.random.randint(len(data_slow)), :, 10], label='Anomalous signal', color='red')
    ax[1][1].plot(data_slow[np.random.randint(len(data_slow)), :, 10], label='Anomalous signal', color='red')

# %% [markdown]
# # Model definition
# LSTM and CNN models

# %%
input_shape = (data_normal.shape[1], 1) if mode == 'mean' else (data_normal.shape[1], data_normal.shape[2])
if mode == 'mean':
    hid_dim1 = int(data_normal.shape[1]/2)
    hid_dim2 = int(data_normal.shape[1]/5)
else:
    hid_dim1 = int(data_normal.shape[2]/2)
    hid_dim2 = int(data_normal.shape[2]/5)
print(f'Input shape: {input_shape}')
print(f'Hidden dim 1: {hid_dim1}')
print(f'Hidden dim 2: {hid_dim2}')

if model == 'lstm':
    encoder = keras.models.Sequential(name='encoder')
    encoder.add(layers.LSTM(hid_dim1, activation='tanh', return_sequences=True, input_shape=input_shape))
    encoder.add(layers.LSTM(hid_dim2, activation='tanh', return_sequences=False, input_shape=input_shape))

    decoder = keras.models.Sequential(name='decoder')
    decoder.add(layers.RepeatVector(sequence_length))
    decoder.add(layers.LSTM(hid_dim2, activation='tanh', return_sequences=True))
    decoder.add(layers.LSTM(hid_dim1, activation='tanh', return_sequences=True))
    decoder.add(layers.TimeDistributed(layers.Dense(input_shape[1])))

    discriminator = keras.models.Sequential(name='discriminator')
    #discriminator.add(layers.LSTM(20, activation='tanh', return_sequences=False))
    discriminator.add(layers.Dense(16, activation='relu'))
    discriminator.add(layers.Dropout(0.2))
    discriminator.add(layers.Dense(1, activation='sigmoid'))
elif model == 'conv':
    encoder = keras.models.Sequential(name='encoder')
    encoder.add(layers.Conv1D(filters=hid_dim1, kernel_size=3, padding="same", strides=2, activation="relu", input_shape=input_shape))
    encoder.add(layers.Conv1D(filters=hid_dim2, kernel_size=3, padding="same", strides=2, activation="relu"))

    decoder = keras.models.Sequential(name='decoder')
    decoder.add(layers.Conv1DTranspose(filters=hid_dim2, kernel_size=3, padding="same", strides=2, activation="relu"))
    decoder.add(layers.Conv1DTranspose(filters=hid_dim1, kernel_size=3, padding="same", strides=2, activation="relu"))
    decoder.add(layers.Conv1DTranspose(filters=data_normal.shape[2], kernel_size=3, padding="same", activation="sigmoid"))

    discriminator = keras.models.Sequential(name='discriminator')
    discriminator.add(layers.Flatten())
    discriminator.add(layers.Dense(16, activation='relu'))
    discriminator.add(layers.Dropout(0.2))
    discriminator.add(layers.Dense(1, activation='sigmoid'))

autoencoder = keras.models.Sequential()
autoencoder.add(encoder)
autoencoder.add(decoder)

encoder_discriminator = keras.models.Sequential()
encoder_discriminator.add(encoder)
encoder_discriminator.add(discriminator)
# Out:
# Input shape: (20, 20)
# Hidden dim 1: 10
# Hidden dim 2: 4
# 2023-07-02 17:10:21.767916: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
encoder.summary()
decoder.summary()
discriminator.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 10)            610
#
#  conv1d_1 (Conv1D)           (None, 5, 4)              124
#
# =================================================================
# Total params: 734
# Trainable params: 734
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_transpose (Conv1DTra  (None, 10, 4)            52
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 20, 10)           130
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 20, 20)           620
#  ranspose)
#
# =================================================================
# Total params: 802
# Trainable params: 802
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 20)                0
#
#  dense (Dense)               (None, 16)                336
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 353
# Trainable params: 353
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
encoder_discriminator.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# # Training

# %%
batchsize = int(len(data_normal) / 5)

def settrainable(model, toset):
    for layer in model.layers:
        layer.trainable = toset
    model.trainable = toset

for epoch in range(epochs):
    np.random.shuffle(data_normal)
    validation_data = data_normal[np.random.choice(len(data_normal), 1000), :]

    for i in range(int(len(data_normal) / batchsize)):
        settrainable(autoencoder, True)
        settrainable(encoder, True)
        settrainable(decoder, True)

        batch = data_normal[i*batchsize:i*batchsize+batchsize]
        autoencoder.train_on_batch(batch, batch)

        settrainable(discriminator, True)
        batchpred = encoder.predict(batch)
        if model == 'conv':
            fakepred = np.random.standard_normal((batchsize, encoder.output_shape[1], encoder.output_shape[2]))
        else: #model == 'lstm':
            fakepred = np.random.standard_normal((batchsize, encoder.output_shape[1]))
        discbatch_x = np.concatenate([batchpred, fakepred])
        discbatch_y = np.concatenate([np.zeros(batchsize), np.ones(batchsize)])
        discriminator.train_on_batch(discbatch_x, discbatch_y)

        settrainable(encoder_discriminator, True)
        settrainable(encoder, True)
        settrainable(discriminator, False)
        encoder_discriminator.train_on_batch(batch, np.ones(batchsize))

    print (f"{epoch+1}/{epochs} Reconstruction Loss:", autoencoder.evaluate(validation_data, validation_data))
    print (f"{epoch+1}/{epochs} Adverserial Loss:", encoder_discriminator.evaluate(validation_data, np.ones(len(validation_data))))
# Out:
# 1462/1462 [==============================] - 1s 415us/step
# 1462/1462 [==============================] - 1s 480us/step
# 1462/1462 [==============================] - 1s 423us/step
# 1462/1462 [==============================] - 1s 450us/step
# 1462/1462 [==============================] - 1s 415us/step
# 32/32 [==============================] - 0s 878us/step - loss: 0.6842
# 1/10 Reconstruction Loss: 0.6841632723808289
# 32/32 [==============================] - 0s 637us/step - loss: 0.6309
# 1/10 Adverserial Loss: 0.6309410333633423
# 1462/1462 [==============================] - 1s 450us/step
# 1462/1462 [==============================] - 1s 438us/step
# 1462/1462 [==============================] - 1s 410us/step
# 1462/1462 [==============================] - 1s 405us/step
# 1462/1462 [==============================] - 1s 472us/step
# 32/32 [==============================] - 0s 863us/step - loss: 0.6748
# 2/10 Reconstruction Loss: 0.67482990026474
# 32/32 [==============================] - 0s 569us/step - loss: 0.5845
# 2/10 Adverserial Loss: 0.5845198035240173
# 1462/1462 [==============================] - 1s 431us/step
# 1462/1462 [==============================] - 1s 511us/step
# 1462/1462 [==============================] - 1s 429us/step
# 1462/1462 [==============================] - 1s 407us/step
# 1462/1462 [==============================] - 1s 405us/step
# 32/32 [==============================] - 0s 850us/step - loss: 0.6640
# 3/10 Reconstruction Loss: 0.6640384793281555
# 32/32 [==============================] - 0s 562us/step - loss: 0.5455
# 3/10 Adverserial Loss: 0.5455350875854492
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 426us/step
# 1462/1462 [==============================] - 1s 404us/step
# 1462/1462 [==============================] - 1s 432us/step
# 1462/1462 [==============================] - 1s 410us/step
# 32/32 [==============================] - 0s 809us/step - loss: 0.6484
# 4/10 Reconstruction Loss: 0.6484086513519287
# 32/32 [==============================] - 0s 519us/step - loss: 0.4902
# 4/10 Adverserial Loss: 0.49019578099250793
# 1462/1462 [==============================] - 1s 415us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 417us/step
# 1462/1462 [==============================] - 1s 404us/step
# 1462/1462 [==============================] - 1s 405us/step
# 32/32 [==============================] - 0s 783us/step - loss: 0.6288
# 5/10 Reconstruction Loss: 0.6288402080535889
# 32/32 [==============================] - 0s 525us/step - loss: 0.4350
# 5/10 Adverserial Loss: 0.43502581119537354
# 1462/1462 [==============================] - 1s 408us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 404us/step
# 32/32 [==============================] - 0s 793us/step - loss: 0.6047
# 6/10 Reconstruction Loss: 0.6047174334526062
# 32/32 [==============================] - 0s 525us/step - loss: 0.3801
# 6/10 Adverserial Loss: 0.3800638020038605
# 1462/1462 [==============================] - 1s 402us/step
# 1462/1462 [==============================] - 1s 404us/step
# 1462/1462 [==============================] - 1s 407us/step
# 1462/1462 [==============================] - 1s 448us/step
# 1462/1462 [==============================] - 1s 424us/step
# 32/32 [==============================] - 0s 991us/step - loss: 0.5720
# 7/10 Reconstruction Loss: 0.5719959139823914
# 32/32 [==============================] - 0s 561us/step - loss: 0.3321
# 7/10 Adverserial Loss: 0.33214670419692993
# 1462/1462 [==============================] - 1s 407us/step
# 1462/1462 [==============================] - 1s 405us/step
# 1462/1462 [==============================] - 1s 407us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 406us/step
# 32/32 [==============================] - 0s 850us/step - loss: 0.5310
# 8/10 Reconstruction Loss: 0.5309613943099976
# 32/32 [==============================] - 0s 598us/step - loss: 0.2764
# 8/10 Adverserial Loss: 0.2763653099536896
# 1462/1462 [==============================] - 1s 405us/step
# 1462/1462 [==============================] - 1s 409us/step
# 1462/1462 [==============================] - 1s 408us/step
# 1462/1462 [==============================] - 1s 411us/step
# 1462/1462 [==============================] - 1s 459us/step
# 32/32 [==============================] - 0s 869us/step - loss: 0.4823
# 9/10 Reconstruction Loss: 0.48233187198638916
# 32/32 [==============================] - 0s 568us/step - loss: 0.2322
# 9/10 Adverserial Loss: 0.2322358787059784
# 1462/1462 [==============================] - 1s 442us/step
# 1462/1462 [==============================] - 1s 406us/step
# 1462/1462 [==============================] - 1s 408us/step
# 1462/1462 [==============================] - 1s 426us/step
# 1462/1462 [==============================] - 1s 413us/step
# 32/32 [==============================] - 0s 853us/step - loss: 0.4253
# 10/10 Reconstruction Loss: 0.42528247833251953
# 32/32 [==============================] - 0s 586us/step - loss: 0.1943
# 10/10 Adverserial Loss: 0.19426260888576508

# %% [markdown]
# # Anomaly detection
# Histogram plots with the reconstruction loss for both normal and anomalous sequences

# %%
n_test_samples = 500

# %%
random_indexes = np.random.choice(len(data_normal), size=n_test_samples)
test_data = data_normal[random_indexes, :]
rec_normal = autoencoder.predict(test_data)

if mode == 'mean':
    normal_loss = np.mean(np.abs(rec_normal - test_data), axis=1)
else:
    normal_loss = np.mean(np.abs(rec_normal - test_data), axis=2)
    normal_loss = np.mean(normal_loss, axis=1)

plt.hist(normal_loss, bins=50)
plt.xlabel("Normal loss")
plt.ylabel("No of examples")
# Out:
# 16/16 [==============================] - 0s 752us/step
# Text(0, 0.5, 'No of examples')

# %%
random_indexes = np.random.choice(len(data_slow), size=n_test_samples)
test_data = data_slow[random_indexes, :]
rec_slow = autoencoder.predict(test_data)

if mode == 'mean':
    anomalous_loss = np.mean(np.abs(rec_slow - test_data), axis=1)
else:
    anomalous_loss = np.mean(np.abs(rec_slow - test_data), axis=2)
    anomalous_loss = np.mean(anomalous_loss, axis=1)

plt.hist(anomalous_loss, bins=50)
plt.xlabel("Anomalous loss")
plt.ylabel("No of examples")
# Out:
# 16/16 [==============================] - 0s 825us/step
# Text(0, 0.5, 'No of examples')

# %% [markdown]
# ### Threshold fine-tuning

# %%
threshold = 0.43

fig, ax = plt.subplots()
ax.scatter(np.arange(n_test_samples), normal_loss, label='Normal')
ax.scatter(np.arange(n_test_samples, n_test_samples*2), anomalous_loss, label='Anomalous')
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error")
plt.ylabel("Reconstruction error")
plt.xlabel("Sample index")
# Out:
# Text(0.5, 0, 'Sample index')

# %% [markdown]
# ### Metrics

# %%
loss = np.concatenate((normal_loss, anomalous_loss))
target = np.concatenate((np.ones(n_test_samples), np.zeros(n_test_samples)))
pred = np.less(loss, threshold)

print(f'F1: {f1_score(target, pred, average="macro"):.3f}')
print(f'Accuracy: {accuracy_score(target, pred):.3f}')
print(f'Precision: {precision_score(target, pred, average="macro"):.3f}')
print(f'Recall: {recall_score(target, pred, average="macro"):.3f}')
# Out:
# F1: 0.664
# Accuracy: 0.665
# Precision: 0.666
# Recall: 0.665

# %% [markdown]
# # Signal reconstruction

# %%
if mode == 'mean':
    sequence = np.random.randint(len(data_normal))
    signal = data_normal[sequence:sequence+1]
    reconstruction = autoencoder.predict(signal)

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.plot(signal.squeeze(), color='green')
    ax.plot(reconstruction.squeeze(), color='red')
elif mode == '86' or mode == 'pca':
    dimension = np.random.randint(86) if mode == '86' else np.random.randint(pca_dim)
    sequence = np.random.randint(len(data_normal))
    signal = data_normal[sequence:sequence+1, :, :]
    reconstruction = autoencoder.predict(signal)

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.plot(signal[0, :, dimension], color='green')
    ax.plot(reconstruction[0, :, dimension], color='red')
# Out:
# 1/1 [==============================] - 0s 21ms/step
